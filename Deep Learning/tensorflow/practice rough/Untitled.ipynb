# %%
from sklearn.datasets import make_circles

# Make 1000 examples
n_samples = 1000

# Create circles
X, y = make_circles(n_samples,
                    noise=0.03,
                    random_state=42)

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

def plot_decision_boundary(model, X, y):
    """
    Plots the decision boundary created by a model predicting on X
    """
    # Define the axis boundaries of the plot and create a meshgrid
    x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + 0.1
    y_min, y_max = X[:, 1].min() - 0.1, X[:, 1].max() + 0.1

    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100),
                        np.linspace(y_min, y_max, 100))

    # create x value (we're gonig to make predictions on these)
    X_in = np.c_[xx.ravel(), yy.ravel()] # stack 2D arrays together

    # Make predictions
    y_pred = model.predict(X_in)

    # Check for multi-class
    if len(y_pred[0]) > 1:
        print("dong multiclass classification")
        # we have to reshape our predictions to get them ready for plotting
        y_pred = np.argmax(y_pred, axis=1).reshape(xx.shape)
    else:
        print("doing binary classification")
        y_pred = np.round(y_pred).reshape(xx.shape)


    # plot the decision boundary
    plt.contourf(xx, yy, y_pred, cmap=plt.cm.RdYlBu, alpha=0.7)
    plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.RdYlBu)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())

# %%
# set random seed
tf.random.set_seed(42)

# create a model
model_7 = tf.keras.Sequential([
    tf.keras.layers.Dense(5, activation="relu"),
    tf.keras.layers.Dense(5, activation="relu"),
    tf.keras.layers.Dense(1, activation="sigmoid")
])

# compile the model
model_7.compile(loss="binary_crossentropy",
               optimizer=tf.keras.optimizers.legacy.Adam(),
               metrics=['accuracy'])

# fit the model
history = model_7.fit(X, y, epochs=100)
# Out:
# Epoch 1/100
# 2023-07-03 11:54:16.221729: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 32/32 [==============================] - 1s 9ms/step - loss: 0.7016 - accuracy: 0.5030
# Epoch 2/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6966 - accuracy: 0.4950
# Epoch 3/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6947 - accuracy: 0.4980
# Epoch 4/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6945 - accuracy: 0.4840
# Epoch 5/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6940 - accuracy: 0.5000
# Epoch 6/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6941 - accuracy: 0.4830
# Epoch 7/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6937 - accuracy: 0.4970
# Epoch 8/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6939 - accuracy: 0.4960
# Epoch 9/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6936 - accuracy: 0.4890
# Epoch 10/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6938 - accuracy: 0.4660
# Epoch 11/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6936 - accuracy: 0.4780
# Epoch 12/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6934 - accuracy: 0.5010
# Epoch 13/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6938 - accuracy: 0.4990
# Epoch 14/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6938 - accuracy: 0.5020
# Epoch 15/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6942 - accuracy: 0.5090
# Epoch 16/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6946 - accuracy: 0.5100
# Epoch 17/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6950 - accuracy: 0.5080
# Epoch 18/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6951 - accuracy: 0.5080
# Epoch 19/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6960 - accuracy: 0.5110
# Epoch 20/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6961 - accuracy: 0.5110
# Epoch 21/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6968 - accuracy: 0.5140
# Epoch 22/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6964 - accuracy: 0.5110
# Epoch 23/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6962 - accuracy: 0.5150
# Epoch 24/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6956 - accuracy: 0.5120
# Epoch 25/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6958 - accuracy: 0.5100
# Epoch 26/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6952 - accuracy: 0.5140
# Epoch 27/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6954 - accuracy: 0.5180
# Epoch 28/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6947 - accuracy: 0.5190
# Epoch 29/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6949 - accuracy: 0.5040
# Epoch 30/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6946 - accuracy: 0.4980
# Epoch 31/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6945 - accuracy: 0.5060
# Epoch 32/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6944 - accuracy: 0.5150
# Epoch 33/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6942 - accuracy: 0.5120
# Epoch 34/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6942 - accuracy: 0.5110
# Epoch 35/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6942 - accuracy: 0.5100
# Epoch 36/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6938 - accuracy: 0.5080
# Epoch 37/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6938 - accuracy: 0.5080
# Epoch 38/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6939 - accuracy: 0.4970
# Epoch 39/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6938 - accuracy: 0.5020
# Epoch 40/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6939 - accuracy: 0.5030
# Epoch 41/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6938 - accuracy: 0.5140
# Epoch 42/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6937 - accuracy: 0.5100
# Epoch 43/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6937 - accuracy: 0.5070
# Epoch 44/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6939 - accuracy: 0.4970
# Epoch 45/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6935 - accuracy: 0.5030
# Epoch 46/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6935 - accuracy: 0.5040
# Epoch 47/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6938 - accuracy: 0.5090
# Epoch 48/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6935 - accuracy: 0.5070
# Epoch 49/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6935 - accuracy: 0.4990
# Epoch 50/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6936 - accuracy: 0.4910
# Epoch 51/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6935 - accuracy: 0.4910
# Epoch 52/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6936 - accuracy: 0.5110
# Epoch 53/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6940 - accuracy: 0.4960
# Epoch 54/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6934 - accuracy: 0.5120
# Epoch 55/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6938 - accuracy: 0.5080
# Epoch 56/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6936 - accuracy: 0.5100
# Epoch 57/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6935 - accuracy: 0.4990
# Epoch 58/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6937 - accuracy: 0.5190
# Epoch 59/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6941 - accuracy: 0.5150
# Epoch 60/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6935 - accuracy: 0.5140
# Epoch 61/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6936 - accuracy: 0.4940
# Epoch 62/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6935 - accuracy: 0.5030
# Epoch 63/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6934 - accuracy: 0.4970
# Epoch 64/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6935 - accuracy: 0.4890
# Epoch 65/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6936 - accuracy: 0.4970
# Epoch 66/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6935 - accuracy: 0.5050
# Epoch 67/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6936 - accuracy: 0.4930
# Epoch 68/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6934 - accuracy: 0.4930
# Epoch 69/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6935 - accuracy: 0.4950
# Epoch 70/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6935 - accuracy: 0.5090
# Epoch 71/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6935 - accuracy: 0.4960
# Epoch 72/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6936 - accuracy: 0.5070
# Epoch 73/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6936 - accuracy: 0.5010
# Epoch 74/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6936 - accuracy: 0.5090
# Epoch 75/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6936 - accuracy: 0.5190
# Epoch 76/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6935 - accuracy: 0.4800
# Epoch 77/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6935 - accuracy: 0.5080
# Epoch 78/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6935 - accuracy: 0.4800
# Epoch 79/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6936 - accuracy: 0.4970
# Epoch 80/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6933 - accuracy: 0.5320
# Epoch 81/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6938 - accuracy: 0.5490
# Epoch 82/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6939 - accuracy: 0.5000
# Epoch 83/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6936 - accuracy: 0.4880
# Epoch 84/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6932 - accuracy: 0.5270
# Epoch 85/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6935 - accuracy: 0.5230
# Epoch 86/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6937 - accuracy: 0.5210
# Epoch 87/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6934 - accuracy: 0.5090
# Epoch 88/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6935 - accuracy: 0.4840
# Epoch 89/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6935 - accuracy: 0.4890
# Epoch 90/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6937 - accuracy: 0.4520
# Epoch 91/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6934 - accuracy: 0.4920
# Epoch 92/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6936 - accuracy: 0.5000
# Epoch 93/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6942 - accuracy: 0.4810
# Epoch 94/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6935 - accuracy: 0.4850
# Epoch 95/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6935 - accuracy: 0.4800
# Epoch 96/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6937 - accuracy: 0.4880
# Epoch 97/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6934 - accuracy: 0.4780
# Epoch 98/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6934 - accuracy: 0.4730
# Epoch 99/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6936 - accuracy: 0.4920
# Epoch 100/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6937 - accuracy: 0.4900

# %%
# Evaluate the model
model_7.evaluate(X, y)
# Out:
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6932 - accuracy: 0.5190
# [0.6932182908058167, 0.5189999938011169]

# %%
# visualize the data
plot_decision_boundary(model_7, X, y)
# Out:
# 313/313 [==============================] - 0s 1ms/step
# doing binary classification

# %%
model_7.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 15
#
#  dense_1 (Dense)             (None, 5)                 30
#
#  dense_2 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 51
# Trainable params: 51
# Non-trainable params: 0
# _________________________________________________________________
