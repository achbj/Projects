# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('./train.csv')
test = pd.read_csv('./test.csv')

# %%
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
train.corr()
# Out:
# /var/folders/jh/_q3zsphn00z4nwx2cszyw4mc0000gn/T/ipykernel_21203/2189804198.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   train.corr()
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train.corr()
# Out:
# /var/folders/jh/_q3zsphn00z4nwx2cszyw4mc0000gn/T/ipykernel_21203/2189804198.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   train.corr()
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# ...

# %%
def miss_values_info(df):
    # Assuming your DataFrame is named 'train'
    # Calculate the percentage of missing values for each column
    missing_percentage = (df.isnull().sum() / len(df)) * 100

    # Create a DataFrame to store the missing value information
    missing_info = pd.DataFrame({
        'Column': df.columns,
        'Missing Values': df.isnull().sum(),
        'Percentage': missing_percentage
    })

    # Filter the DataFrame to include only columns with missing values
    missing_info = missing_info[missing_info['Missing Values'] > 0]
    
    # Sort the DataFrame by the percentage of missing values in descending order
    missing_info = missing_info.sort_values(by='Percentage', ascending=False)

    # Display the columns with the most missing values
    return missing_info

# %%
train_missing = miss_values_info(train)
print('train missing info: \n', train_missing)
# Out:
# train missing info:
#                      Column  Missing Values  Percentage
# PoolQC              PoolQC            1453   99.520548
# MiscFeature    MiscFeature            1406   96.301370
# Alley                Alley            1369   93.767123
# Fence                Fence            1179   80.753425
# FireplaceQu    FireplaceQu             690   47.260274
# LotFrontage    LotFrontage             259   17.739726
# GarageType      GarageType              81    5.547945
# GarageYrBlt    GarageYrBlt              81    5.547945
# GarageFinish  GarageFinish              81    5.547945
# GarageQual      GarageQual              81    5.547945
# GarageCond      GarageCond              81    5.547945
# BsmtExposure  BsmtExposure              38    2.602740
# BsmtFinType2  BsmtFinType2              38    2.602740
# BsmtFinType1  BsmtFinType1              37    2.534247
# BsmtCond          BsmtCond              37    2.534247
# BsmtQual          BsmtQual              37    2.534247
# ...

# %%
test_missing = miss_values_info(test)
print('train missing info: \n', test_missing)
# Out:
# train missing info:
#                      Column  Missing Values  Percentage
# PoolQC              PoolQC            1456   99.794380
# MiscFeature    MiscFeature            1408   96.504455
# Alley                Alley            1352   92.666210
# Fence                Fence            1169   80.123372
# FireplaceQu    FireplaceQu             730   50.034270
# LotFrontage    LotFrontage             227   15.558602
# GarageCond      GarageCond              78    5.346127
# GarageYrBlt    GarageYrBlt              78    5.346127
# GarageQual      GarageQual              78    5.346127
# GarageFinish  GarageFinish              78    5.346127
# GarageType      GarageType              76    5.209047
# BsmtCond          BsmtCond              45    3.084304
# BsmtExposure  BsmtExposure              44    3.015764
# BsmtQual          BsmtQual              44    3.015764
# BsmtFinType1  BsmtFinType1              42    2.878684
# BsmtFinType2  BsmtFinType2              42    2.878684
# ...

# %%
train.drop(columns=['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu'], axis=0, inplace=True)
test.drop(columns=['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu'], axis=0, inplace=True)

# %%
miss_values_info(train).Column
# Out:
# LotFrontage      LotFrontage
# GarageType        GarageType
# GarageYrBlt      GarageYrBlt
# GarageFinish    GarageFinish
# GarageQual        GarageQual
# GarageCond        GarageCond
# BsmtExposure    BsmtExposure
# BsmtFinType2    BsmtFinType2
# BsmtQual            BsmtQual
# BsmtCond            BsmtCond
# BsmtFinType1    BsmtFinType1
# MasVnrType        MasVnrType
# MasVnrArea        MasVnrArea
# Electrical        Electrical
# Name: Column, dtype: object

# %%
train[miss_values_info(train).Column.tolist()]
# Out:
#       LotFrontage GarageType  GarageYrBlt GarageFinish GarageQual GarageCond  \
# 0            65.0     Attchd       2003.0          RFn         TA         TA
# 1            80.0     Attchd       1976.0          RFn         TA         TA
# 2            68.0     Attchd       2001.0          RFn         TA         TA
# 3            60.0     Detchd       1998.0          Unf         TA         TA
# 4            84.0     Attchd       2000.0          RFn         TA         TA
# ...           ...        ...          ...          ...        ...        ...
# 1455         62.0     Attchd       1999.0          RFn         TA         TA
# 1456         85.0     Attchd       1978.0          Unf         TA         TA
# 1457         66.0     Attchd       1941.0          RFn         TA         TA
# 1458         68.0     Attchd       1950.0          Unf         TA         TA
# 1459         75.0     Attchd       1965.0          Fin         TA         TA
#
# ...

# %%
train[miss_values_info(train).Column.tolist()]
# Out:
#       LotFrontage GarageType  GarageYrBlt GarageFinish GarageQual GarageCond  \
# 0            65.0     Attchd       2003.0          RFn         TA         TA
# 1            80.0     Attchd       1976.0          RFn         TA         TA
# 2            68.0     Attchd       2001.0          RFn         TA         TA
# 3            60.0     Detchd       1998.0          Unf         TA         TA
# 4            84.0     Attchd       2000.0          RFn         TA         TA
# ...           ...        ...          ...          ...        ...        ...
# 1455         62.0     Attchd       1999.0          RFn         TA         TA
# 1456         85.0     Attchd       1978.0          Unf         TA         TA
# 1457         66.0     Attchd       1941.0          RFn         TA         TA
# 1458         68.0     Attchd       1950.0          Unf         TA         TA
# 1459         75.0     Attchd       1965.0          Fin         TA         TA
#
# ...

# %%
train[miss_values_info(train).Column.tolist()].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   LotFrontage   1201 non-null   float64
#  1   GarageType    1379 non-null   object
#  2   GarageYrBlt   1379 non-null   float64
#  3   GarageFinish  1379 non-null   object
#  4   GarageQual    1379 non-null   object
#  5   GarageCond    1379 non-null   object
#  6   BsmtExposure  1422 non-null   object
#  7   BsmtFinType2  1422 non-null   object
#  8   BsmtQual      1423 non-null   object
#  9   BsmtCond      1423 non-null   object
#  10  BsmtFinType1  1423 non-null   object
#  11  MasVnrType    1452 non-null   object
#  12  MasVnrArea    1452 non-null   float64
#  13  Electrical    1459 non-null   object
# dtypes: float64(3), object(11)
# memory usage: 159.8+ KB

# %% [markdown]
# lets fill all the null values in both train and test sets before we work on categorical values

# %%
from sklearn.impute import SimpleImputer

def impute_missing_values(df):
    # List of float type columns with missing values
    float_columns = df.select_dtypes(include=['float64']).columns.tolist()

    # List of object type columns with missing values
    object_columns = df.select_dtypes(include=['object']).columns.tolist()

    # Impute missing values for float type columns with the median
    float_imputer = SimpleImputer(strategy='median')
    df[float_columns] = float_imputer.fit_transform(df[float_columns])

    # Impute missing values for object type columns with the most frequent category ('mode')
    object_imputer = SimpleImputer(strategy='most_frequent')
    df[object_columns] = object_imputer.fit_transform(df[object_columns])

    return df

# %%
train = impute_missing_values(train)
test = impute_missing_values(test)

# %%
train_missing = miss_values_info(train)
print('train missing info: \n', train_missing)
# Out:
# train missing info:
#  Empty DataFrame
# Columns: [Column, Missing Values, Percentage]
# Index: []

# %%
test_missing = miss_values_info(test)
print('train missing info: \n', test_missing)
# Out:
# train missing info:
#  Empty DataFrame
# Columns: [Column, Missing Values, Percentage]
# Index: []

# %%
# Initialize an empty list to store the binary categorical columns
binary_categorical_columns = []

# Iterate through object columns
for column in train.select_dtypes(include=['object']):
    unique_values = train[column].nunique()
    if unique_values == 2:
        binary_categorical_columns.append(column)

# Display the binary categorical columns
print("Binary Categorical Columns:")
print(binary_categorical_columns)
# Out:
# Binary Categorical Columns:
# ['Street', 'Utilities', 'CentralAir']

# %%
# Select object type columns
object_columns = train.select_dtypes(include=['object'])

# Display the total number of unique values in each object column
for column in object_columns.columns:
    unique_values = object_columns[column].nunique()
    print(f"Column '{column}' has {unique_values} unique values.")
# Out:
# Column 'MSZoning' has 5 unique values.
# Column 'Street' has 2 unique values.
# Column 'LotShape' has 4 unique values.
# Column 'LandContour' has 4 unique values.
# Column 'Utilities' has 2 unique values.
# Column 'LotConfig' has 5 unique values.
# Column 'LandSlope' has 3 unique values.
# Column 'Neighborhood' has 25 unique values.
# Column 'Condition1' has 9 unique values.
# Column 'Condition2' has 8 unique values.
# Column 'BldgType' has 5 unique values.
# Column 'HouseStyle' has 8 unique values.
# Column 'RoofStyle' has 6 unique values.
# Column 'RoofMatl' has 8 unique values.
# Column 'Exterior1st' has 15 unique values.
# Column 'Exterior2nd' has 16 unique values.
# Column 'MasVnrType' has 4 unique values.
# Column 'ExterQual' has 4 unique values.
# Column 'ExterCond' has 5 unique values.
# Column 'Foundation' has 6 unique values.
# Column 'BsmtQual' has 4 unique values.
# Column 'BsmtCond' has 4 unique values.
# Column 'BsmtExposure' has 4 unique values.
# ...

# %%
def get_unique_values(df, column_name):
    # Check if the column name is present in the DataFrame
    if column_name in df.columns:
        # Select the unique values in the specified column
        unique_values = df[column_name].unique()
        return unique_values
    else:
        return None  # Return None if the column does not exist in the DataFrame

# %%
mszoning_unique_values = get_unique_values(train, 'MSZoning')
print(mszoning_unique_values)
# Out:
# ['RL' 'RM' 'C (all)' 'FV' 'RH']

# %%
from sklearn.preprocessing import LabelEncoder

def encode_categorical_columns(df):
    # Identify categorical columns
    categorical_columns = df.select_dtypes(include=['object']).columns.tolist()
    
    # Initialize a LabelEncoder
    label_encoder = LabelEncoder()
    
    # Encode each object column
    for column in object_columns:
        df[column] = label_encoder.fit_transform(df[column])
    
    return df

# %%
encoded_train = encode_categorical_columns(train)
encoded_test = encode_categorical_columns(test)

# %%
encoded_train
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0        1          60         3         65.0     8450       1         3
# 1        2          20         3         80.0     9600       1         3
# 2        3          60         3         68.0    11250       1         0
# 3        4          70         3         60.0     9550       1         0
# 4        5          60         3         84.0    14260       1         0
# ...    ...         ...       ...          ...      ...     ...       ...
# 1455  1456          60         3         62.0     7917       1         3
# 1456  1457          20         3         85.0    13175       1         3
# 1457  1458          70         3         66.0     9042       1         3
# 1458  1459          20         3         68.0     9717       1         3
# 1459  1460          20         3         75.0     9937       1         3
#
#       LandContour  Utilities  LotConfig  ...  EnclosedPorch  3SsnPorch  \
# ...

# %%
encoded_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 76 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   LotShape       1460 non-null   int64
#  7   LandContour    1460 non-null   int64
#  8   Utilities      1460 non-null   int64
#  9   LotConfig      1460 non-null   int64
#  10  LandSlope      1460 non-null   int64
#  11  Neighborhood   1460 non-null   int64
#  12  Condition1     1460 non-null   int64
#  13  Condition2     1460 non-null   int64
#  14  BldgType       1460 non-null   int64
#  15  HouseStyle     1460 non-null   int64
#  16  OverallQual    1460 non-null   int64
#  17  OverallCond    1460 non-null   int64
# ...

# %%
encoded_train.corr()
# Out:
#                      Id  MSSubClass  MSZoning  LotFrontage   LotArea  \
# Id             1.000000    0.011156 -0.006096    -0.009921 -0.033226
# MSSubClass     0.011156    1.000000  0.035900    -0.356718 -0.139781
# MSZoning      -0.006096    0.035900  1.000000    -0.105961 -0.034452
# LotFrontage   -0.009921   -0.356718 -0.105961     1.000000  0.304522
# LotArea       -0.033226   -0.139781 -0.034452     0.304522  1.000000
# ...                 ...         ...       ...          ...       ...
# MoSold         0.021172   -0.013585 -0.031496     0.010451  0.001205
# YrSold         0.000712   -0.021407 -0.020628     0.006380 -0.014261
# SaleType       0.019773    0.012464  0.097437    -0.031412  0.012292
# SaleCondition -0.005806   -0.024940  0.009494     0.058857  0.034169
# SalePrice     -0.021917   -0.084284 -0.166872     0.334771  0.263843
#
#                  Street  LotShape  LandContour  Utilities  LotConfig  ...  \
# ...

# %%
# Specify the correlation threshold
correlation_threshold = 0.20

# Create a list of columns with high correlation to 'SalePrice' in the training set
high_corr_columns_train = encoded_train.columns[encoded_train.corr()['SalePrice'] > correlation_threshold]

# Filter the training set to include only the selected columns
filtered_encoded_train = encoded_train[high_corr_columns_train.drop('SalePrice', errors='ignore')]

# Filter the test set to include only the selected columns
filtered_encoded_test = encoded_test[high_corr_columns_train.drop('SalePrice', errors='ignore')]

# %%
filtered_encoded_train
# Out:
#       LotFrontage  LotArea  Neighborhood  OverallQual  YearBuilt  \
# 0            65.0     8450             5            7       2003
# 1            80.0     9600            24            6       1976
# 2            68.0    11250             5            7       2001
# 3            60.0     9550             6            7       1915
# 4            84.0    14260            15            8       2000
# ...           ...      ...           ...          ...        ...
# 1455         62.0     7917             8            6       1999
# 1456         85.0    13175            14            6       1978
# 1457         66.0     9042             6            7       1941
# 1458         68.0     9717            12            5       1950
# 1459         75.0     9937             7            5       1965
#
#       YearRemodAdd  RoofStyle  MasVnrArea  Foundation  BsmtFinSF1  ...  \
# 0             2003          1       196.0           2         706  ...
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# Fit and transform on the training data
train_scaled = scaler.fit_transform(filtered_encoded_train)

# Transform the test data using the same scaler
test_scaled = scaler.transform(filtered_encoded_test)

# %%
y_trains = encoded_train['SalePrice']

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(train_scaled, y_trains, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Create a Linear Regression model
model = LinearRegression()

# Train the model on the training data
model.fit(X_train, y_train)

# Make predictions on the validation data
y_pred = model.predict(X_val)

# Evaluate the model using metrics
mae = mean_absolute_error(y_val, y_pred)
mse = mean_squared_error(y_val, y_pred)
rmse = np.sqrt(mse)

print(f"Mean Absolute Error: {mae}")
print(f"Mean Squared Error: {mse}")
print(f"Root Mean Squared Error: {rmse}")
# Out:
# Mean Absolute Error: 23797.094050421278
# Mean Squared Error: 1433942782.5711226
# Root Mean Squared Error: 37867.43696860302

# %%
y_pred = model.predict(test_scaled)

# %%
# Create a DataFrame for submission
submission_df = pd.DataFrame({'Id': test['Id'], 'SalePrice': y_pred})

# Save the submission DataFrame to a CSV file
submission_df.to_csv('sample_submission.csv', index=False)

# %%
import tensorflow as tf
from tensorflow import keras

# Define your neural network model
model = keras.Sequential([
    keras.layers.Dense(64, activation='relu', input_shape=(train_scaled.shape[1],)),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(1)  # Output layer for regression
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model with a 20% validation split
history = model.fit(train_scaled, y_trains, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 2023-10-07 20:46:26.910088: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 37/37 [==============================] - 1s 10ms/step - loss: 38819012608.0000 - val_loss: 39917514752.0000
# Epoch 2/50
# 37/37 [==============================] - 0s 6ms/step - loss: 38817730560.0000 - val_loss: 39915372544.0000
# Epoch 3/50
# 37/37 [==============================] - 0s 6ms/step - loss: 38814494720.0000 - val_loss: 39909949440.0000
# Epoch 4/50
# 37/37 [==============================] - 0s 6ms/step - loss: 38807650304.0000 - val_loss: 39898587136.0000
# Epoch 5/50
# 37/37 [==============================] - 0s 6ms/step - loss: 38793723904.0000 - val_loss: 39879512064.0000
# Epoch 6/50
# 37/37 [==============================] - 0s 6ms/step - loss: 38772916224.0000 - val_loss: 39850450944.0000
# Epoch 7/50
# 37/37 [==============================] - 0s 6ms/step - loss: 38741954560.0000 - val_loss: 39810293760.0000
# Epoch 8/50
# ...

# %%
# Make predictions on the test set
predictions = model.predict(test_scaled)

# Save the predictions along with the 'Id' column
submission_df['SalePrice'] = predictions
submission_df.to_csv('sample_submission.csv', index=False)
# Out:
# 46/46 [==============================] - 0s 2ms/step

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Random Forest Regressor
rf_regressor = RandomForestRegressor(random_state=42)
rf_regressor.fit(X_train, y_train)
rf_predictions = rf_regressor.predict(X_val)

# Gradient Boosting Regressor
gb_regressor = GradientBoostingRegressor(random_state=42)
gb_regressor.fit(X_train, y_train)
gb_predictions = gb_regressor.predict(X_val)

# SVM Regressor
svm_regressor = SVR()
svm_regressor.fit(X_train, y_train)
svm_predictions = svm_regressor.predict(X_val)

# %%
# Evaluate the models
def evaluate_model(predictions, y_true):
    mse = mean_squared_error(y_true, predictions)
    mae = mean_absolute_error(y_true, predictions)
    r2 = r2_score(y_true, predictions)
    return mse, mae, r2

# %%
rf_metrics = evaluate_model(rf_predictions, y_val)
gb_metrics = evaluate_model(gb_predictions, y_val)
svm_metrics = evaluate_model(svm_predictions, y_val)

print("Random Forest Regressor Metrics:")
print("Mean Squared Error (MSE):", rf_metrics[0])
print("Mean Absolute Error (MAE):", rf_metrics[1])
print("R-squared (R2) Score:", rf_metrics[2])
print("\n")

print("Gradient Boosting Regressor Metrics:")
print("Mean Squared Error (MSE):", gb_metrics[0])
print("Mean Absolute Error (MAE):", gb_metrics[1])
print("R-squared (R2) Score:", gb_metrics[2])
print("\n")

print("SVM Regressor Metrics:")
print("Mean Squared Error (MSE):", svm_metrics[0])
print("Mean Absolute Error (MAE):", svm_metrics[1])
print("R-squared (R2) Score:", svm_metrics[2])
# Out:
# Random Forest Regressor Metrics:
# Mean Squared Error (MSE): 817621817.3367162
# Mean Absolute Error (MAE): 18103.063652968034
# R-squared (R2) Score: 0.8934045573484735
#
#
# Gradient Boosting Regressor Metrics:
# Mean Squared Error (MSE): 844229614.1692394
# Mean Absolute Error (MAE): 18359.56612115511
# R-squared (R2) Score: 0.8899356309803105
#
#
# SVM Regressor Metrics:
# Mean Squared Error (MSE): 7854861285.56854
# Mean Absolute Error (MAE): 59509.527671335774
# R-squared (R2) Score: -0.024058309046687487

# %%
rfr_predictions = rf_regressor.predict(test_scaled)
# Save the predictions along with the 'Id' column
submission_df['SalePrice'] = rfr_predictions
submission_df.to_csv('sample_submission.csv', index=False)

# %%
gbr_predictions = gb_regressor.predict(test_scaled)
# Save the predictions along with the 'Id' column
submission_df['SalePrice'] = rfr_predictions
submission_df.to_csv('sample_submission.csv', index=False)

# %%
import tensorflow as tf
from tensorflow import keras

model = keras.Sequential([
    keras.layers.Input(shape=(X_train.shape[1],)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(1)  # Output layer for regression
])

# %%
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_val, y_val))
# Out:
# Epoch 1/100
# 37/37 [==============================] - 1s 11ms/step - loss: 31844356096.0000 - mean_absolute_error: 170621.5938 - val_loss: 34284859392.0000 - val_mean_absolute_error: 176896.9531
# Epoch 2/100
# 37/37 [==============================] - 0s 7ms/step - loss: 31844794368.0000 - mean_absolute_error: 170603.4844 - val_loss: 34282162176.0000 - val_mean_absolute_error: 176889.0469
# Epoch 3/100
# 37/37 [==============================] - 0s 7ms/step - loss: 31850840064.0000 - mean_absolute_error: 170586.5312 - val_loss: 34292482048.0000 - val_mean_absolute_error: 176880.2344
# Epoch 4/100
# 37/37 [==============================] - 0s 8ms/step - loss: 31840882688.0000 - mean_absolute_error: 170631.1875 - val_loss: 34262620160.0000 - val_mean_absolute_error: 176870.6094
# Epoch 5/100
# 37/37 [==============================] - 0s 7ms/step - loss: 31830292480.0000 - mean_absolute_error: 170639.0938 - val_loss: 34273955840.0000 - val_mean_absolute_error: 176852.4844
# Epoch 6/100
# ...

# %%
val_loss, val_mae = model.evaluate(X_val, y_val)
print(f"Validation Loss: {val_loss}, Validation MAE: {val_mae}")
# Out:
# 10/10 [==============================] - 0s 4ms/step - loss: 32606982144.0000 - mean_absolute_error: 173718.0000
# Validation Loss: 32606982144.0, Validation MAE: 173718.0

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Make predictions on the validation set
y_pred = model.predict(X_val)

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_val, y_pred)

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_val, y_pred)

# Calculate R-squared (R2) score
r2 = r2_score(y_val, y_pred)

print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"R-squared (R2) Score: {r2}")
# Out:
# 10/10 [==============================] - 0s 2ms/step
# Mean Squared Error (MSE): 32606983276.70924
# Mean Absolute Error (MAE): 173718.01547073992
# R-squared (R2) Score: -3.251055613013742

# %%
from pycaret.regression import RegressionExperiment

def pycaret_score(X, y):
    s = RegressionExperiment()
    s.setup(X, target = y, session_id = 123)
    
    best = s.compare_models()

# %%
pycaret_score(train_scaled, y_trains)
# Out:
# <style type="text/css">
# #T_0fb23_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0fb23">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0fb23_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_0fb23_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0fb23_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0fb23_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_0fb23_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_0fb23_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0fb23_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_0fb23_row1_col1" class="data row1 col1" >SalePrice</td>
#     </tr>
#     <tr>
#       <th id="T_0fb23_level0_row2" class="row_heading level0 row2" >2</th>
# ...
