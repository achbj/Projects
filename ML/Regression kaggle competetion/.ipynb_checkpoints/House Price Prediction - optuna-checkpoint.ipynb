# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('./train.csv')
test = pd.read_csv('./test.csv')

# %%
def miss_values_info(df):
    # Assuming your DataFrame is named 'train'
    # Calculate the percentage of missing values for each column
    missing_percentage = (df.isnull().sum() / len(df)) * 100

    # Create a DataFrame to store the missing value information
    missing_info = pd.DataFrame({
        'Column': df.columns,
        'Missing Values': df.isnull().sum(),
        'Percentage': missing_percentage
    })

    # Filter the DataFrame to include only columns with missing values
    missing_info = missing_info[missing_info['Missing Values'] > 0]
    
    # Sort the DataFrame by the percentage of missing values in descending order
    missing_info = missing_info.sort_values(by='Percentage', ascending=False)

    # Display the columns with the most missing values
    return missing_info

# %%
train_missing = miss_values_info(train)
print('train missing info: \n', train_missing)
# Out:
# train missing info:
#                      Column  Missing Values  Percentage
# PoolQC              PoolQC            1453   99.520548
# MiscFeature    MiscFeature            1406   96.301370
# Alley                Alley            1369   93.767123
# Fence                Fence            1179   80.753425
# FireplaceQu    FireplaceQu             690   47.260274
# LotFrontage    LotFrontage             259   17.739726
# GarageType      GarageType              81    5.547945
# GarageYrBlt    GarageYrBlt              81    5.547945
# GarageFinish  GarageFinish              81    5.547945
# GarageQual      GarageQual              81    5.547945
# GarageCond      GarageCond              81    5.547945
# BsmtExposure  BsmtExposure              38    2.602740
# BsmtFinType2  BsmtFinType2              38    2.602740
# BsmtFinType1  BsmtFinType1              37    2.534247
# BsmtCond          BsmtCond              37    2.534247
# BsmtQual          BsmtQual              37    2.534247
# MasVnrArea      MasVnrArea               8    0.547945
# MasVnrType      MasVnrType               8    0.547945
# Electrical      Electrical               1    0.068493

# %%
train.drop(columns=['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu'], axis=0, inplace=True)
test.drop(columns=['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu'], axis=0, inplace=True)

# %%
from sklearn.impute import SimpleImputer

def impute_missing_values(df):
    # List of float type columns with missing values
    float_columns = df.select_dtypes(include=['float64']).columns.tolist()

    # List of object type columns with missing values
    object_columns = df.select_dtypes(include=['object']).columns.tolist()

    # Impute missing values for float type columns with the median
    float_imputer = SimpleImputer(strategy='median')
    df[float_columns] = float_imputer.fit_transform(df[float_columns])

    # Impute missing values for object type columns with the most frequent category ('mode')
    object_imputer = SimpleImputer(strategy='most_frequent')
    df[object_columns] = object_imputer.fit_transform(df[object_columns])

    return df

# %%
train = impute_missing_values(train)
test = impute_missing_values(test)

# %%
from sklearn.preprocessing import LabelEncoder

def encode_categorical_columns(df):
    # Identify categorical columns
    categorical_columns = df.select_dtypes(include=['object']).columns.tolist()
    
    # Initialize a LabelEncoder
    label_encoder = LabelEncoder()
    
    # List of object type columns with missing values
    object_columns = df.select_dtypes(include=['object']).columns.tolist()
    
    # Encode each object column
    for column in object_columns:
        df[column] = label_encoder.fit_transform(df[column])
    
    return df

# %%
encoded_train = encode_categorical_columns(train)
encoded_test = encode_categorical_columns(test)

# %%
# # Specify the correlation threshold
# correlation_threshold = 0.01

# # Create a list of columns with high correlation to 'SalePrice' in the training set
# high_corr_columns_train = encoded_train.columns[encoded_train.corr()['SalePrice'] > correlation_threshold]

# # Filter the training set to include only the selected columns
# filtered_encoded_train = encoded_train[high_corr_columns_train.drop('SalePrice', errors='ignore')]

# # Filter the test set to include only the selected columns
# filtered_encoded_test = encoded_test[high_corr_columns_train.drop('SalePrice', errors='ignore')]

# %%
encoded_trains = encoded_train.drop(columns=['SalePrice'], axis=0)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# Fit and transform on the training data
train_scaled = scaler.fit_transform(encoded_trains)

# Transform the test data using the same scaler
test_scaled = scaler.transform(encoded_test)

# %%
y_trains = encoded_train['SalePrice']

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(train_scaled, y_trains, test_size=0.2, random_state=42)

# %% [markdown]
# # Pycaret

# %%
from pycaret import *

# %%
from pycaret.regression import *
exp_name = setup(data = train_scaled,  target = y_trains)
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_40a8e_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_40a8e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40a8e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_40a8e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40a8e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_40a8e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_40a8e_row0_col1" class="data row0 col1" >4534</td>
#     </tr>
#     <tr>
#       <th id="T_40a8e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_40a8e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_40a8e_row1_col1" class="data row1 col1" >SalePrice</td>
#     </tr>
#     <tr>
#       <th id="T_40a8e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_40a8e_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_40a8e_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_40a8e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_40a8e_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_40a8e_row3_col1" class="data row3 col1" >(1460, 76)</td>
#     </tr>
#     <tr>
#       <th id="T_40a8e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_40a8e_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_40a8e_row4_col1" class="data row4 col1" >(1460, 76)</td>
#     </tr>
#     <tr>
#       <th id="T_40a8e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_40a8e_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_40a8e_row5_col1" class="data row5 col1" >(1021, 76)</td>
#     </tr>
#     <tr>
#       <th id="T_40a8e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_40a8e_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_40a8e_row6_col1" class="data row6 col1" >(439, 76)</td>
#     </tr>
#     <tr>
#       <th id="T_40a8e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_40a8e_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_40a8e_row7_col1" class="data row7 col1" >75</td>
#     </tr>
#     <tr>
#       <th id="T_40a8e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_40a8e_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_40a8e_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_40a8e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_40a8e_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_40a8e_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_40a8e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_40a8e_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_40a8e_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_40a8e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_40a8e_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_40a8e_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_40a8e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_40a8e_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_40a8e_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_40a8e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_40a8e_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_40a8e_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_40a8e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_40a8e_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_40a8e_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_40a8e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_40a8e_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_40a8e_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_40a8e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_40a8e_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_40a8e_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_40a8e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_40a8e_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_40a8e_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_40a8e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_40a8e_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_40a8e_row18_col1" class="data row18 col1" >38f6</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_f8fbd th {
#   text-align: left;
# }
# #T_f8fbd_row0_col0, #T_f8fbd_row0_col1, #T_f8fbd_row0_col2, #T_f8fbd_row0_col3, #T_f8fbd_row0_col5, #T_f8fbd_row0_col6, #T_f8fbd_row1_col0, #T_f8fbd_row1_col4, #T_f8fbd_row2_col0, #T_f8fbd_row2_col1, #T_f8fbd_row2_col2, #T_f8fbd_row2_col3, #T_f8fbd_row2_col4, #T_f8fbd_row2_col5, #T_f8fbd_row2_col6, #T_f8fbd_row3_col0, #T_f8fbd_row3_col1, #T_f8fbd_row3_col2, #T_f8fbd_row3_col3, #T_f8fbd_row3_col4, #T_f8fbd_row3_col5, #T_f8fbd_row3_col6, #T_f8fbd_row4_col0, #T_f8fbd_row4_col1, #T_f8fbd_row4_col2, #T_f8fbd_row4_col3, #T_f8fbd_row4_col4, #T_f8fbd_row4_col5, #T_f8fbd_row4_col6, #T_f8fbd_row5_col0, #T_f8fbd_row5_col1, #T_f8fbd_row5_col2, #T_f8fbd_row5_col3, #T_f8fbd_row5_col4, #T_f8fbd_row5_col5, #T_f8fbd_row5_col6, #T_f8fbd_row6_col0, #T_f8fbd_row6_col1, #T_f8fbd_row6_col2, #T_f8fbd_row6_col3, #T_f8fbd_row6_col4, #T_f8fbd_row6_col5, #T_f8fbd_row6_col6, #T_f8fbd_row7_col0, #T_f8fbd_row7_col1, #T_f8fbd_row7_col2, #T_f8fbd_row7_col3, #T_f8fbd_row7_col4, #T_f8fbd_row7_col5, #T_f8fbd_row7_col6, #T_f8fbd_row8_col0, #T_f8fbd_row8_col1, #T_f8fbd_row8_col2, #T_f8fbd_row8_col3, #T_f8fbd_row8_col4, #T_f8fbd_row8_col5, #T_f8fbd_row8_col6, #T_f8fbd_row9_col0, #T_f8fbd_row9_col1, #T_f8fbd_row9_col2, #T_f8fbd_row9_col3, #T_f8fbd_row9_col4, #T_f8fbd_row9_col5, #T_f8fbd_row9_col6, #T_f8fbd_row10_col0, #T_f8fbd_row10_col1, #T_f8fbd_row10_col2, #T_f8fbd_row10_col3, #T_f8fbd_row10_col4, #T_f8fbd_row10_col5, #T_f8fbd_row10_col6, #T_f8fbd_row11_col0, #T_f8fbd_row11_col1, #T_f8fbd_row11_col2, #T_f8fbd_row11_col3, #T_f8fbd_row11_col4, #T_f8fbd_row11_col5, #T_f8fbd_row11_col6, #T_f8fbd_row12_col0, #T_f8fbd_row12_col1, #T_f8fbd_row12_col2, #T_f8fbd_row12_col3, #T_f8fbd_row12_col4, #T_f8fbd_row12_col5, #T_f8fbd_row12_col6, #T_f8fbd_row13_col0, #T_f8fbd_row13_col1, #T_f8fbd_row13_col2, #T_f8fbd_row13_col3, #T_f8fbd_row13_col4, #T_f8fbd_row13_col5, #T_f8fbd_row13_col6, #T_f8fbd_row14_col0, #T_f8fbd_row14_col1, #T_f8fbd_row14_col2, #T_f8fbd_row14_col3, #T_f8fbd_row14_col4, #T_f8fbd_row14_col5, #T_f8fbd_row14_col6, #T_f8fbd_row15_col0, #T_f8fbd_row15_col1, #T_f8fbd_row15_col2, #T_f8fbd_row15_col3, #T_f8fbd_row15_col4, #T_f8fbd_row15_col5, #T_f8fbd_row15_col6, #T_f8fbd_row16_col0, #T_f8fbd_row16_col1, #T_f8fbd_row16_col2, #T_f8fbd_row16_col3, #T_f8fbd_row16_col4, #T_f8fbd_row16_col5, #T_f8fbd_row16_col6 {
#   text-align: left;
# }
# #T_f8fbd_row0_col4, #T_f8fbd_row1_col1, #T_f8fbd_row1_col2, #T_f8fbd_row1_col3, #T_f8fbd_row1_col5, #T_f8fbd_row1_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_f8fbd_row0_col7, #T_f8fbd_row1_col7, #T_f8fbd_row2_col7, #T_f8fbd_row3_col7, #T_f8fbd_row5_col7, #T_f8fbd_row8_col7, #T_f8fbd_row9_col7, #T_f8fbd_row10_col7, #T_f8fbd_row13_col7, #T_f8fbd_row14_col7, #T_f8fbd_row15_col7, #T_f8fbd_row16_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_f8fbd_row4_col7, #T_f8fbd_row6_col7, #T_f8fbd_row7_col7, #T_f8fbd_row11_col7, #T_f8fbd_row12_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_f8fbd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8fbd_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f8fbd_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_f8fbd_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_f8fbd_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_f8fbd_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_f8fbd_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_f8fbd_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_f8fbd_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8fbd_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_f8fbd_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_f8fbd_row0_col1" class="data row0 col1" >17498.6413</td>
#       <td id="T_f8fbd_row0_col2" class="data row0 col2" >895323792.3290</td>
#       <td id="T_f8fbd_row0_col3" class="data row0 col3" >29351.4495</td>
#       <td id="T_f8fbd_row0_col4" class="data row0 col4" >0.8414</td>
#       <td id="T_f8fbd_row0_col5" class="data row0 col5" >0.1457</td>
#       <td id="T_f8fbd_row0_col6" class="data row0 col6" >0.1044</td>
#       <td id="T_f8fbd_row0_col7" class="data row0 col7" >0.0780</td>
#     </tr>
#     <tr>
#       <th id="T_f8fbd_level0_row1" class="row_heading level0 row1" >gbr</th>
#       <td id="T_f8fbd_row1_col0" class="data row1 col0" >Gradient Boosting Regressor</td>
#       <td id="T_f8fbd_row1_col1" class="data row1 col1" >16893.1567</td>
#       <td id="T_f8fbd_row1_col2" class="data row1 col2" >863256865.3753</td>
#       <td id="T_f8fbd_row1_col3" class="data row1 col3" >28428.3412</td>
#       <td id="T_f8fbd_row1_col4" class="data row1 col4" >0.8370</td>
#       <td id="T_f8fbd_row1_col5" class="data row1 col5" >0.1380</td>
#       <td id="T_f8fbd_row1_col6" class="data row1 col6" >0.0998</td>
#       <td id="T_f8fbd_row1_col7" class="data row1 col7" >0.0450</td>
#     </tr>
#     <tr>
#       <th id="T_f8fbd_level0_row2" class="row_heading level0 row2" >huber</th>
#       <td id="T_f8fbd_row2_col0" class="data row2 col0" >Huber Regressor</td>
#       <td id="T_f8fbd_row2_col1" class="data row2 col1" >18215.5807</td>
#       <td id="T_f8fbd_row2_col2" class="data row2 col2" >913605227.6089</td>
#       <td id="T_f8fbd_row2_col3" class="data row2 col3" >29402.3664</td>
#       <td id="T_f8fbd_row2_col4" class="data row2 col4" >0.8342</td>
#       <td id="T_f8fbd_row2_col5" class="data row2 col5" >0.1492</td>
#       <td id="T_f8fbd_row2_col6" class="data row2 col6" >0.1076</td>
#       <td id="T_f8fbd_row2_col7" class="data row2 col7" >0.0060</td>
#     </tr>
#     <tr>
#       <th id="T_f8fbd_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_f8fbd_row3_col0" class="data row3 col0" >Random Forest Regressor</td>
#       <td id="T_f8fbd_row3_col1" class="data row3 col1" >17747.5458</td>
#       <td id="T_f8fbd_row3_col2" class="data row3 col2" >915781179.0044</td>
#       <td id="T_f8fbd_row3_col3" class="data row3 col3" >29532.8180</td>
#       <td id="T_f8fbd_row3_col4" class="data row3 col4" >0.8336</td>
#       <td id="T_f8fbd_row3_col5" class="data row3 col5" >0.1468</td>
#       <td id="T_f8fbd_row3_col6" class="data row3 col6" >0.1063</td>
#       <td id="T_f8fbd_row3_col7" class="data row3 col7" >0.0990</td>
#     </tr>
#     <tr>
#       <th id="T_f8fbd_level0_row4" class="row_heading level0 row4" >en</th>
#       <td id="T_f8fbd_row4_col0" class="data row4 col0" >Elastic Net</td>
#       <td id="T_f8fbd_row4_col1" class="data row4 col1" >18736.8072</td>
#       <td id="T_f8fbd_row4_col2" class="data row4 col2" >976279521.9925</td>
#       <td id="T_f8fbd_row4_col3" class="data row4 col3" >30615.0165</td>
#       <td id="T_f8fbd_row4_col4" class="data row4 col4" >0.8288</td>
#       <td id="T_f8fbd_row4_col5" class="data row4 col5" >0.1477</td>
#       <td id="T_f8fbd_row4_col6" class="data row4 col6" >0.1085</td>
#       <td id="T_f8fbd_row4_col7" class="data row4 col7" >0.0040</td>
#     </tr>
#     <tr>
#       <th id="T_f8fbd_level0_row5" class="row_heading level0 row5" >br</th>
#       <td id="T_f8fbd_row5_col0" class="data row5 col0" >Bayesian Ridge</td>
#       <td id="T_f8fbd_row5_col1" class="data row5 col1" >19058.0764</td>
#       <td id="T_f8fbd_row5_col2" class="data row5 col2" >997027946.5220</td>
#       <td id="T_f8fbd_row5_col3" class="data row5 col3" >30510.4692</td>
#       <td id="T_f8fbd_row5_col4" class="data row5 col4" >0.8148</td>
#       <td id="T_f8fbd_row5_col5" class="data row5 col5" >0.1685</td>
#       <td id="T_f8fbd_row5_col6" class="data row5 col6" >0.1149</td>
#       <td id="T_f8fbd_row5_col7" class="data row5 col7" >0.0050</td>
#     </tr>
#     <tr>
#       <th id="T_f8fbd_level0_row6" class="row_heading level0 row6" >ridge</th>
#       <td id="T_f8fbd_row6_col0" class="data row6 col0" >Ri

# %%
best_model_tuned = tune_model(best_model)
# Out:
# <style type="text/css">
# #T_94d15_row10_col0, #T_94d15_row10_col1, #T_94d15_row10_col2, #T_94d15_row10_col3, #T_94d15_row10_col4, #T_94d15_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_94d15">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_94d15_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_94d15_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_94d15_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_94d15_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_94d15_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_94d15_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_94d15_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_94d15_row0_col0" class="data row0 col0" >17369.1243</td>
#       <td id="T_94d15_row0_col1" class="data row0 col1" >830650347.9047</td>
#       <td id="T_94d15_row0_col2" class="data row0 col2" >28821.0053</td>
#       <td id="T_94d15_row0_col3" class="data row0 col3" >0.8508</td>
#       <td id="T_94d15_row0_col4" class="data row0 col4" >0.1132</td>
#       <td id="T_94d15_row0_col5" class="data row0 col5" >0.0868</td>
#     </tr>
#     <tr>
#       <th id="T_94d15_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_94d15_row1_col0" class="data row1 col0" >17961.7579</td>
#       <td id="T_94d15_row1_col1" class="data row1 col1" >774662914.3582</td>
#       <td id="T_94d15_row1_col2" class="data row1 col2" >27832.7669</td>
#       <td id="T_94d15_row1_col3" class="data row1 col3" >0.8824</td>
#       <td id="T_94d15_row1_col4" class="data row1 col4" >0.1576</td>
#       <td id="T_94d15_row1_col5" class="data row1 col5" >0.1110</td>
#     </tr>
#     <tr>
#       <th id="T_94d15_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_94d15_row2_col0" class="data row2 col0" >17730.2604</td>
#       <td id="T_94d15_row2_col1" class="data row2 col1" >1567591313.9300</td>
#       <td id="T_94d15_row2_col2" class="data row2 col2" >39592.8190</td>
#       <td id="T_94d15_row2_col3" class="data row2 col3" >0.8161</td>
#       <td id="T_94d15_row2_col4" class="data row2 col4" >0.1619</td>
#       <td id="T_94d15_row2_col5" class="data row2 col5" >0.1083</td>
#     </tr>
#     <tr>
#       <th id="T_94d15_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_94d15_row3_col0" class="data row3 col0" >15367.0123</td>
#       <td id="T_94d15_row3_col1" class="data row3 col1" >594215052.5076</td>
#       <td id="T_94d15_row3_col2" class="data row3 col2" >24376.5267</td>
#       <td id="T_94d15_row3_col3" class="data row3 col3" >0.7953</td>
#       <td id="T_94d15_row3_col4" class="data row3 col4" >0.1365</td>
#       <td id="T_94d15_row3_col5" class="data row3 col5" >0.1000</td>
#     </tr>
#     <tr>
#       <th id="T_94d15_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_94d15_row4_col0" class="data row4 col0" >20584.7641</td>
#       <td id="T_94d15_row4_col1" class="data row4 col1" >1316274101.9784</td>
#       <td id="T_94d15_row4_col2" class="data row4 col2" >36280.4920</td>
#       <td id="T_94d15_row4_col3" class="data row4 col3" >0.8366</td>
#       <td id="T_94d15_row4_col4" class="data row4 col4" >0.1382</td>
#       <td id="T_94d15_row4_col5" class="data row4 col5" >0.0992</td>
#     </tr>
#     <tr>
#       <th id="T_94d15_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_94d15_row5_col0" class="data row5 col0" >19408.7312</td>
#       <td id="T_94d15_row5_col1" class="data row5 col1" >656364805.8343</td>
#       <td id="T_94d15_row5_col2" class="data row5 col2" >25619.6176</td>
#       <td id="T_94d15_row5_col3" class="data row5 col3" >0.8591</td>
#       <td id="T_94d15_row5_col4" class="data row5 col4" >0.1891</td>
#       <td id="T_94d15_row5_col5" class="data row5 col5" >0.1436</td>
#     </tr>
#     <tr>
#       <th id="T_94d15_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_94d15_row6_col0" class="data row6 col0" >16944.2185</td>
#       <td id="T_94d15_row6_col1" class="data row6 col1" >768582574.4227</td>
#       <td id="T_94d15_row6_col2" class="data row6 col2" >27723.3219</td>
#       <td id="T_94d15_row6_col3" class="data row6 col3" >0.8937</td>
#       <td id="T_94d15_row6_col4" class="data row6 col4" >0.1436</td>
#       <td id="T_94d15_row6_col5" class="data row6 col5" >0.1013</td>
#     </tr>
#     <tr>
#       <th id="T_94d15_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_94d15_row7_col0" class="data row7 col0" >17196.2167</td>
#       <td id="T_94d15_row7_col1" class="data row7 col1" >714376648.0666</td>
#       <td id="T_94d15_row7_col2" class="data row7 col2" >26727.8254</td>
#       <td id="T_94d15_row7_col3" class="data row7 col3" >0.9010</td>
#       <td id="T_94d15_row7_col4" class="data row7 col4" >0.1300</td>
#       <td id="T_94d15_row7_col5" class="data row7 col5" >0.0983</td>
#     </tr>
#     <tr>
#       <th id="T_94d15_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_94d15_row8_col0" class="data row8 col0" >20556.7159</td>
#       <td id="T_94d15_row8_col1" class="data row8 col1" >1561164150.2146</td>
#       <td id="T_94d15_row8_col2" class="data row8 col2" >39511.5698</td>
#       <td id="T_94d15_row8_col3" class="data row8 col3" >0.6337</td>
#       <td id="T_94d15_row8_col4" class="data row8 col4" >0.1936</td>
#       <td id="T_94d15_row8_col5" class="data row8 col5" >0.1356</td>
#     </tr>
#     <tr>
#       <th id="T_94d15_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_94d15_row9_col0" class="data row9 col0" >19205.4036</td>
#       <td id="T_94d15_row9_col1" class="data row9 col1" >770757564.4938</td>
#       <td id="T_94d15_row9_col2" class="data row9 col2" >27762.5209</td>
#       <td id="T_94d15_row9_col3" class="data row9 col3" >0.8690</td>
#       <td id="T_94d15_row9_col4" class="data row9 col4" >0.1589</td>
#       <td id="T_94d15_row9_col5" class="data row9 col5" >0.1182</td>
#     </tr>
#     <tr>
#       <th id="T_94d15_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_94d15_row10_col0" class="data row10 col0" >18232.4205</td>
#       <td id="T_94d15_row10_col1" class="data row10 col1" >955463947.3711</td>
#       <td id="T_94d15_row10_col2" class="data row10 col2" >30424.8465</td>
#       <td id="T_94d15_row10_col3" class="data row10 col3" >0.8338</td>
#       <td id="T_94d15_row10_col4" class="data row10 col4" >0.1523</td>
#       <td id="T_94d15_row10_col5" class="data row10 col5" >0.1102</td>
#     </tr>
#     <tr>
#       <th id="T_94d15_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_94d15_row11_col0" class="data row11 col0" >1589.9913</td>
#       <td id="T_94d15_row11_col1" class="data row11 col1" >355970406.9523</td>
#       <td id="T_94d15_row11_col2" class="data row11 col2" >5458.2653</td>
#       <td id="T_94d15_row11_col3" class="data row11 col3" >0.0738</td>
#       <td id="T_94d15_row11_col4" class="data row11 col4" >0.0240</td>
#       <td id="T_94d15_row11_col5" class="data row11 col5" >0.0168</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
exp_1 = setup(data = train_scaled,  target = y_trains)
top4 = compare_models(n_select = 4)
stacker = stack_models(top4)

# %%
y_pred = best_model_tuned.predict(test_scaled)

# %%
# Create a DataFrame for submission
submission_df = pd.DataFrame({'Id': test['Id'], 'SalePrice': y_pred})

# Save the submission DataFrame to a CSV file
submission_df.to_csv('sample_submission.csv', index=False)
