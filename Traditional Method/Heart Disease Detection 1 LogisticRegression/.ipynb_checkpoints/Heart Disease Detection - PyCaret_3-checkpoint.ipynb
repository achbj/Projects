# %%
import pandas as pd
from pycaret.classification import *

# %%
df = pd.read_csv('./heart.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
exp = setup(df, target = 'target')
# Out:
# <style type="text/css">
# #T_c5e5a_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c5e5a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c5e5a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c5e5a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5e5a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c5e5a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c5e5a_row0_col1" class="data row0 col1" >3142</td>
#     </tr>
#     <tr>
#       <th id="T_c5e5a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c5e5a_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c5e5a_row1_col1" class="data row1 col1" >target</td>
#     </tr>
#     <tr>
#       <th id="T_c5e5a_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models(include=['lr'], fold=60, sort='AUC')
# Out:
# <style type="text/css">
# #T_296b0 th {
#   text-align: left;
# }
# #T_296b0_row0_col0 {
#   text-align: left;
# }
# #T_296b0_row0_col1, #T_296b0_row0_col2, #T_296b0_row0_col3, #T_296b0_row0_col4, #T_296b0_row0_col5, #T_296b0_row0_col6, #T_296b0_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_296b0_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_296b0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_296b0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_296b0_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_296b0_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_296b0_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_296b0_level0_col4" class="col_heading level0 col4" >Prec.</th>
# ...
