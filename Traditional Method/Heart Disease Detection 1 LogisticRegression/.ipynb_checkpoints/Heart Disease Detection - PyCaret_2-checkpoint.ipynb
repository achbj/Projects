# %%
import pandas as pd
from pycaret.classification import *

# %%
df = pd.read_csv('./heart.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
clf = setup(data=df, target='target', session_id=111, remove_outliers=True, multicollinearity_threshold=1.5)
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_13e1d_row8_col1, #T_13e1d_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_13e1d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13e1d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_13e1d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13e1d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_13e1d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_13e1d_row0_col1" class="data row0 col1" >111</td>
#     </tr>
#     <tr>
#       <th id="T_13e1d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_13e1d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_13e1d_row1_col1" class="data row1 col1" >target</td>
#     </tr>
#     <tr>
#       <th id="T_13e1d_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
clf.data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 608    64    1   0       145   212    0        0      132      0      2.0
# 522    67    0   2       152   277    0        1      172      0      0.0
# 143    34    1   3       118   182    0        0      174      0      0.0
# 185    57    1   0       165   289    1        0      124      0      1.0
# 485    62    1   1       120   281    0        0      103      0      1.4
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 917    47    1   2       130   253    0        1      179      0      0.0
# 919    38    1   3       120   231    0        1      182      1      3.8
# 457    39    0   2       138   220    0        1      152      0      0.0
# 348    43    1   0       132   247    1        0      143      1      0.1
#
#       slope  ca  thal  target
# 608       1   2     1       0
# ...

# %%
lr = create_model('lr', fold=15, return_train_score=True)
# Out:
# <style type="text/css">
# #T_83af7_row30_col0, #T_83af7_row30_col1, #T_83af7_row30_col2, #T_83af7_row30_col3, #T_83af7_row30_col4, #T_83af7_row30_col5, #T_83af7_row30_col6, #T_83af7_row32_col0, #T_83af7_row32_col1, #T_83af7_row32_col2, #T_83af7_row32_col3, #T_83af7_row32_col4, #T_83af7_row32_col5, #T_83af7_row32_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_83af7">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83af7_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_83af7_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_83af7_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_83af7_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_83af7_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_83af7_level0_col5" class="col_heading level0 col5" >Kappa</th>
# ...
