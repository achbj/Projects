# %%
import pandas as pd
from pycaret.classification import *

# %%
df = pd.read_csv('./heart.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.shape
# Out:
# (1025, 14)

# %%
exp = setup(df, target = 'target')
# Out:
# <style type="text/css">
# #T_5d6bc_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5d6bc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5d6bc_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5d6bc_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d6bc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5d6bc_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5d6bc_row0_col1" class="data row0 col1" >369</td>
#     </tr>
#     <tr>
#       <th id="T_5d6bc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5d6bc_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5d6bc_row1_col1" class="data row1 col1" >target</td>
#     </tr>
#     <tr>
#       <th id="T_5d6bc_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models(fold=60, sort='AUC')
# Out:
# <style type="text/css">
# #T_df881 th {
#   text-align: left;
# }
# ...

# %%
# create_api(best_model, 'rf_HDD_api')

# %%
# !python rf_HDD_api.py

# %%
create_app(best_model)
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "/Users/achbj/opt/miniconda3/envs/nn/lib/python3.10/site-packages/gradio/routes.py", line 439, in run_predict
#     output = await app.get_blocks().process_api(
#   File "/Users/achbj/opt/miniconda3/envs/nn/lib/python3.10/site-packages/gradio/blocks.py", line 1384, in process_api
#     result = await self.call_function(
#   File "/Users/achbj/opt/miniconda3/envs/nn/lib/python3.10/site-packages/gradio/blocks.py", line 1089, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "/Users/achbj/opt/miniconda3/envs/nn/lib/python3.10/site-packages/anyio/to_thread.py", line 33, in run_sync
# ...
