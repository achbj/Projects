# %%
import pandas as pd
from pycaret.classification import *

# %%
df = pd.read_csv('./heart.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
clf = setup(data=df, target='target', session_id=111, remove_outliers=True, multicollinearity_threshold=1.5)
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_99509_row8_col1, #T_99509_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_99509">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99509_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_99509_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99509_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_99509_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_99509_row0_col1" class="data row0 col1" >111</td>
#     </tr>
#     <tr>
#       <th id="T_99509_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_99509_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_99509_row1_col1" class="data row1 col1" >target</td>
#     </tr>
#     <tr>
#       <th id="T_99509_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
clf.data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 608    64    1   0       145   212    0        0      132      0      2.0
# 522    67    0   2       152   277    0        1      172      0      0.0
# 143    34    1   3       118   182    0        0      174      0      0.0
# 185    57    1   0       165   289    1        0      124      0      1.0
# 485    62    1   1       120   281    0        0      103      0      1.4
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 917    47    1   2       130   253    0        1      179      0      0.0
# 919    38    1   3       120   231    0        1      182      1      3.8
# 457    39    0   2       138   220    0        1      152      0      0.0
# 348    43    1   0       132   247    1        0      143      1      0.1
#
#       slope  ca  thal  target
# 608       1   2     1       0
# ...

# %%
lr = create_model('lr', fold=15, return_train_score=True)
# Out:
# <style type="text/css">
# #T_347b6_row30_col0, #T_347b6_row30_col1, #T_347b6_row30_col2, #T_347b6_row30_col3, #T_347b6_row30_col4, #T_347b6_row30_col5, #T_347b6_row30_col6, #T_347b6_row32_col0, #T_347b6_row32_col1, #T_347b6_row32_col2, #T_347b6_row32_col3, #T_347b6_row32_col4, #T_347b6_row32_col5, #T_347b6_row32_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_347b6">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_347b6_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_347b6_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_347b6_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_347b6_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_347b6_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_347b6_level0_col5" class="col_heading level0 col5" >Kappa</th>
# ...

# %%
tuned_lr = tune_model(lr)
# Out:
# <style type="text/css">
# #T_f74c1_row10_col0, #T_f74c1_row10_col1, #T_f74c1_row10_col2, #T_f74c1_row10_col3, #T_f74c1_row10_col4, #T_f74c1_row10_col5, #T_f74c1_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_f74c1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f74c1_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_f74c1_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_f74c1_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_f74c1_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_f74c1_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_f74c1_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_f74c1_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
tuned_lr = tune_model(lr, optimize='Accuracy')
# Out:
# <style type="text/css">
# #T_81510_row10_col0, #T_81510_row10_col1, #T_81510_row10_col2, #T_81510_row10_col3, #T_81510_row10_col4, #T_81510_row10_col5, #T_81510_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_81510">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_81510_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_81510_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_81510_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_81510_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_81510_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_81510_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_81510_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
tuned_lr_1 = tune_model(lr, optimize='F1')
# Out:
# <style type="text/css">
# #T_2aa08_row10_col0, #T_2aa08_row10_col1, #T_2aa08_row10_col2, #T_2aa08_row10_col3, #T_2aa08_row10_col4, #T_2aa08_row10_col5, #T_2aa08_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_2aa08">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2aa08_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_2aa08_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_2aa08_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_2aa08_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_2aa08_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_2aa08_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_2aa08_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
tuned_lr_2 = tune_model(lr, optimize='Accuracy', search_library='optuna')
# Out:
# <style type="text/css">
# #T_c3e8b_row10_col0, #T_c3e8b_row10_col1, #T_c3e8b_row10_col2, #T_c3e8b_row10_col3, #T_c3e8b_row10_col4, #T_c3e8b_row10_col5, #T_c3e8b_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_c3e8b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3e8b_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_c3e8b_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_c3e8b_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_c3e8b_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_c3e8b_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_c3e8b_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_c3e8b_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
tuned_lr_2
# Out:
# LogisticRegression(C=9.9729683447424, class_weight={}, dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=1000, multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=111, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
tuned_lr = automl(optimize='Accuracy')

# %%
tuned_lr
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='sqrt',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_samples_leaf=1,
#                      min_samples_split=2, min_weight_fraction_leaf=0.0,
#                      n_estimators=100, n_jobs=-1, oob_score=False,
#                      random_state=111, verbose=0, warm_start=False)
