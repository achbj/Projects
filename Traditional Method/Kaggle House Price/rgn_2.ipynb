# %%
import pandas as pd
from pycaret.regression import *

# %%
train = pd.read_csv('./data/train.csv')
test = pd.read_csv('./data/test.csv')

# %%
rgn = setup(train, target="SalePrice", ignore_features=["ID"], low_variance_threshold=0.1)
best_model = compare_models(sort='RMSE')
# Out:
# <style type="text/css">
# #T_65417_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_65417">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_65417_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_65417_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_65417_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_65417_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_65417_row0_col1" class="data row0 col1" >8642</td>
#     </tr>
#     <tr>
#       <th id="T_65417_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_65417_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_65417_row1_col1" class="data row1 col1" >SalePrice</td>
#     </tr>
#     <tr>
#       <th id="T_65417_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_65417_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_65417_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_65417_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_65417_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_65417_row3_col1" class="data row3 col1" >(1460, 81)</td>
#     </tr>
#     <tr>
#       <th id="T_65417_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_65417_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_65417_row4_col1" class="data row4 col1" >(1460, 87)</td>
#     </tr>
#     <tr>
#       <th id="T_65417_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_65417_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_65417_row5_col1" class="data row5 col1" >(1021, 87)</td>
#     </tr>
#     <tr>
#       <th id="T_65417_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_65417_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_65417_row6_col1" class="data row6 col1" >(439, 87)</td>
#     </tr>
#     <tr>
#       <th id="T_65417_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_65417_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_65417_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_65417_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_65417_row8_col0" class="data row8 col0" >Ordinal features</td>
#       <td id="T_65417_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_65417_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_65417_row9_col0" class="data row9 col0" >Numeric features</td>
#       <td id="T_65417_row9_col1" class="data row9 col1" >37</td>
#     </tr>
#     <tr>
#       <th id="T_65417_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_65417_row10_col0" class="data row10 col0" >Categorical features</td>
#       <td id="T_65417_row10_col1" class="data row10 col1" >43</td>
#     </tr>
#     <tr>
#       <th id="T_65417_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_65417_row11_col0" class="data row11 col0" >Rows with missing values</td>
#       <td id="T_65417_row11_col1" class="data row11 col1" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_65417_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_65417_row12_col0" class="data row12 col0" >Preprocess</td>
#       <td id="T_65417_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_65417_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_65417_row13_col0" class="data row13 col0" >Imputation type</td>
#       <td id="T_65417_row13_col1" class="data row13 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_65417_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_65417_row14_col0" class="data row14 col0" >Numeric imputation</td>
#       <td id="T_65417_row14_col1" class="data row14 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_65417_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_65417_row15_col0" class="data row15 col0" >Categorical imputation</td>
#       <td id="T_65417_row15_col1" class="data row15 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_65417_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_65417_row16_col0" class="data row16 col0" >Maximum one-hot encoding</td>
#       <td id="T_65417_row16_col1" class="data row16 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_65417_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_65417_row17_col0" class="data row17 col0" >Encoding method</td>
#       <td id="T_65417_row17_col1" class="data row17 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_65417_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_65417_row18_col0" class="data row18 col0" >Low variance threshold</td>
#       <td id="T_65417_row18_col1" class="data row18 col1" >0.100000</td>
#     </tr>
#     <tr>
#       <th id="T_65417_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_65417_row19_col0" class="data row19 col0" >Fold Generator</td>
#       <td id="T_65417_row19_col1" class="data row19 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_65417_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_65417_row20_col0" class="data row20 col0" >Fold Number</td>
#       <td id="T_65417_row20_col1" class="data row20 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_65417_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_65417_row21_col0" class="data row21 col0" >CPU Jobs</td>
#       <td id="T_65417_row21_col1" class="data row21 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_65417_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_65417_row22_col0" class="data row22 col0" >Use GPU</td>
#       <td id="T_65417_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_65417_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_65417_row23_col0" class="data row23 col0" >Log Experiment</td>
#       <td id="T_65417_row23_col1" class="data row23 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_65417_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_65417_row24_col0" class="data row24 col0" >Experiment Name</td>
#       <td id="T_65417_row24_col1" class="data row24 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_65417_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_65417_row25_col0" class="data row25 col0" >USI</td>
#       <td id="T_65417_row25_col1" class="data row25 col1" >0afd</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_ad00b th {
#   text-align: left;
# }
# #T_ad00b_row0_col0, #T_ad00b_row1_col0, #T_ad00b_row1_col1, #T_ad00b_row1_col2, #T_ad00b_row1_col3, #T_ad00b_row1_col4, #T_ad00b_row1_col5, #T_ad00b_row1_col6, #T_ad00b_row2_col0, #T_ad00b_row2_col1, #T_ad00b_row2_col2, #T_ad00b_row2_col3, #T_ad00b_row2_col4, #T_ad00b_row2_col5, #T_ad00b_row2_col6, #T_ad00b_row3_col0, #T_ad00b_row3_col1, #T_ad00b_row3_col2, #T_ad00b_row3_col3, #T_ad00b_row3_col4, #T_ad00b_row3_col5, #T_ad00b_row3_col6, #T_ad00b_row4_col0, #T_ad00b_row4_col1, #T_ad00b_row4_col2, #T_ad00b_row4_col3, #T_ad00b_row4_col4, #T_ad00b_row4_col5, #T_ad00b_row4_col6, #T_ad00b_row5_col0, #T_ad00b_row5_col1, #T_ad00b_row5_col2, #T_ad00b_row5_col3, #T_ad00b_row5_col4, #T_ad00b_row5_col5, #T_ad00b_row5_col6, #T_ad00b_row6_col0, #T_ad00b_row6_col1, #T_ad00b_row6_col2, #T_ad00b_row6_col3, #T_ad00b_row6_col4, #T_ad00b_row6_col5, #T_ad00b_row6_col6, #T_ad00b_row7_col0, #T_ad00b_row7_col1, #T_ad00b_row7_col2, #T_ad00b_row7_col3, #T_ad00b_row7_col4, #T_ad00b_row7_col5, #T_ad00b_row7_col6, #T_ad00b_row8_col0, #T_ad00b_row8_col1, #T_ad00b_row8_col2, #T_ad00b_row8_col3, #T_ad00b_row8_col4, #T_ad00b_row8_col5, #T_ad00b_row8_col6, #T_ad00b_row9_col0, #T_ad00b_row9_col1, #T_ad00b_row9_col2, #T_ad00b_row9_col3, #T_ad00b_row9_col4, #T_ad00b_row9_col5, #T_ad00b_row9_col6, #T_ad00b_row10_col0, #T_ad00b_row10_col1, #T_ad00b_row10_col2, #T_ad00b_row10_col3, #T_ad00b_row10_col4, #T_ad00b_row10_col5, #T_ad00b_row10_col6, #T_ad00b_row11_col0, #T_ad00b_row11_col1, #T_ad00b_row11_col2, #T_ad00b_row11_col3, #T_ad00b_row11_col4, #T_ad00b_row11_col5, #T_ad00b_row11_col6, #T_ad00b_row12_col0, #T_ad00b_row12_col1, #T_ad00b_row12_col2, #T_ad00b_row12_col3, #T_ad00b_row12_col4, #T_ad00b_row12_col5, #T_ad00b_row12_col6, #T_ad00b_row13_col0, #T_ad00b_row13_col1, #T_ad00b_row13_col2, #T_ad00b_row13_col3, #T_ad00b_row13_col4, #T_ad00b_row13_col5, #T_ad00b_row13_col6, #T_ad00b_row14_col0, #T_ad00b_row14_col1, #T_ad00b_row14_col2, #T_ad00b_row14_col3, #T_ad00b_row14_col4, #T_ad00b_row14_col5, #T_ad00b_row14_col6, #T_ad00b_row15_col0, #T_ad00b_row15_col1, #T_ad00b_row15_col2, #T_ad00b_row15_col3, #T_ad00b_row15_col4, #T_ad00b_row15_col5, #T_ad00b_row15_col6, #T_ad00b_row16_col0, #T_ad00b_row16_col1, #T_ad00b_row16_col2, #T_ad00b_row16_col3, #T_ad00b_row16_col4, #T_ad00b_row16_col5, #T_ad00b_row16_col6, #T_ad00b_row17_col0, #T_ad00b_row17_col1, #T_ad00b_row17_col2, #T_ad00b_row17_col3, #T_ad00b_row17_col4, #T_ad00b_row17_col5, #T_ad00b_row17_col6, #T_ad00b_row18_col0, #T_ad00b_row18_col1, #T_ad00b_row18_col2, #T_ad00b_row18_col3, #T_ad00b_row18_col4, #T_ad00b_row18_col5, #T_ad00b_row18_col6 {
#   text-align: left;
# }
# #T_ad00b_row0_col1, #T_ad00b_row0_col2, #T_ad00b_row0_col3, #T_ad00b_row0_col4, #T_ad00b_row0_col5, #T_ad00b_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ad00b_row0_col7, #T_ad00b_row1_col7, #T_ad00b_row2_col7, #T_ad00b_row3_col7, #T_ad00b_row4_col7, #T_ad00b_row5_col7, #T_ad00b_row6_col7, #T_ad00b_row7_col7, #T_ad00b_row8_col7, #T_ad00b_row9_col7, #T_ad00b_row10_col7, #T_ad00b_row11_col7, #T_ad00b_row13_col7, #T_ad00b_row14_col7, #T_ad00b_row15_col7, #T_ad00b_row16_col7, #T_ad00b_row17_col7, #T_ad00b_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ad00b_row12_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ad00b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ad00b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ad00b_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ad00b_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ad00b_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ad00b_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ad00b_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ad00b_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_ad00b_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad00b_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_ad00b_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_ad00b_row0_col1" class="data row0 col1" >15694.0842</td>
#       <td id="T_ad00b_row0_col2" class="data row0 col2" >796331203.4804</td>
#       <td id="T_ad00b_row0_col3" class="data row0 col3" >27037.1578</td>
#       <td id="T_ad00b_row0_col4" class="data row0 col4" >0.8712</td>
#       <td id="T_ad00b_row0_col5" class="data row0 col5" >0.1309</td>
#       <td id="T_ad00b_row0_col6" class="data row0 col6" >0.0910</td>
#       <td id="T_ad00b_row0_col7" class="data row0 col7" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_ad00b_level0_row1" class="row_heading level0 row1" >gbr</th>
#       <td id="T_ad00b_row1_col0" class="data row1 col0" >Gradient Boosting Regressor</td>
#       <td id="T_ad00b_row1_col1" class="data row1 col1" >16924.0953</td>
#       <td id="T_ad00b_row1_col2" class="data row1 col2" >895179622.5581</td>
#       <td id="T_ad00b_row1_col3" class="data row1 col3" >28802.5840</td>
#       <td id="T_ad00b_row1_col4" class="data row1 col4" >0.8533</td>
#       <td id="T_ad00b_row1_col5" class="data row1 col5" >0.1391</td>
#       <td id="T_ad00b_row1_col6" class="data row1 col6" >0.0983</td>
#       <td id="T_ad00b_row1_col7" class="data row1 col7" >0.0950</td>
#     </tr>
#     <tr>
#       <th id="T_ad00b_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_ad00b_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_ad00b_row2_col1" class="data row2 col1" >18150.8509</td>
#       <td id="T_ad00b_row2_col2" class="data row2 col2" >968004664.0596</td>
#       <td id="T_ad00b_row2_col3" class="data row2 col3" >30137.4884</td>
#       <td id="T_ad00b_row2_col4" class="data row2 col4" >0.8409</td>
#       <td id="T_ad00b_row2_col5" class="data row2 col5" >0.1520</td>
#       <td id="T_ad00b_row2_col6" class="data row2 col6" >0.1089</td>
#       <td id="T_ad00b_row2_col7" class="data row2 col7" >0.1600</td>
#     </tr>
#     <tr>
#       <th id="T_ad00b_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_ad00b_row3_col0" class="data row3 col0" >Extra Trees Regressor</td>
#       <td id="T_ad00b_row3_col1" class="data row3 col1" >17997.5411</td>
#       <td id="T_ad00b_row3_col2" class="data row3 col2" >1019021953.9859</td>
#       <td id="T_ad00b_row3_col3" class="data row3 col3" >30737.7879</td>
#       <td id="T_ad00b_row3_col4" class="data row3 col4" >0.8297</td>
#       <td id="T_ad00b_row3_col5" class="data row3 col5" >0.1544</td>
#       <td id="T_ad00b_row3_col6" class="data row3 col6" >0.1090</td>
#       <td id="T_ad00b_row3_col7" class="data row3 col7" >0.1510</td>
#     </tr>
#     <tr>
#       <th id="T_ad00b_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_ad00b_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_ad00b_row4_col1" class="data row4 col1" >18661.0124</td>
#       <td id="T_ad00b_row4_col2" class="data row4 col2" >1062849342.3644</td>
#       <td id="T_ad00b_row4_col3" class="data row4 col3" >31474.2231</td>
#       <td id="T_ad00b_row4_col4" class="data row4 col4" >0.8262</td>
#       <td id="T_ad00b_row4_col5" class="data row4 col5" >0.1502</td>
#       <td id="T_ad00b_row4_col6" class="data row4 col6" >0.1074</td>
#       <td id="T_ad00b_row4_col7" class="data row4 col7" >0.0920</td>
#     </tr>
#     <tr>
#       <th id="T_ad00b_level0_row5" class="row_heading level0 row5" >llar</th>
#       <td id="T_ad00b_row5_col0" class="data row5 col0" >Lasso Least Angle Regression</td>
#       <td id="T_ad00b_row5_col1" class="data row5 col1" >20991.4867</td>
#       <td id="T_ad00b_row5_col2" class="data row5 col2" >1276278642.9709</td>
#       <td id="T_ad00b_row5_col3" class="data row5 col3" >33827.1181</td>
#       <td id="T_ad00b_row5_col4" class="data row5 col

# %%
cbr = create_model('catboost', verbose=False)

# %%
predict_model(best_model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_26917">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26917_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_26917_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_26917_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_26917_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_26917_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_26917_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_26917_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26917_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_26917_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_26917_row0_col1" class="data row0 col1" >16814.2887</td>
#       <td id="T_26917_row0_col2" class="data row0 col2" >974007724.3399</td>
#       <td id="T_26917_row0_col3" class="data row0 col3" >31209.0968</td>
#       <td id="T_26917_row0_col4" class="data row0 col4" >0.8601</td>
#       <td id="T_26917_row0_col5" class="data row0 col5" >0.1266</td>
#       <td id="T_26917_row0_col6" class="data row0 col6" >0.0880</td>
#     </tr>
#   </tbody>
# </table>
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 594    595          20       RL         88.0     7990   Pave   NaN      IR1
# 1294  1295          20       RL         60.0     8172   Pave   NaN      Reg
# 351    352         120       RL          NaN     5271   Pave   NaN      IR1
# 603    604         160       FV         30.0     3182   Pave  Pave      Reg
# 172    173         160       RL         44.0     5306   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 405    406          20       RL          NaN     9991   Pave   NaN      IR1
# 1201  1202          60       RL         80.0    10400   Pave   NaN      Reg
# 625    626          20       RL         87.0    10000   Pave   NaN      IR1
# 898    899          20       RL        100.0    12919   Pave   NaN      IR1
# 668    669          20       RL          NaN    14175   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolQC  Fence MiscFeature MiscVal MoSold  \
# 594          Lvl    AllPub  ...    NaN  MnPrv         NaN       0      4
# 1294         Lvl    AllPub  ...    NaN    NaN         NaN       0      4
# 351          Low    AllPub  ...    NaN    NaN         NaN       0     12
# 603          Lvl    AllPub  ...    NaN    NaN         NaN       0      6
# 172          Lvl    AllPub  ...    NaN    NaN         NaN       0      6
# ...          ...       ...  ...    ...    ...         ...     ...    ...
# 405          Lvl    AllPub  ...    NaN   GdWo         NaN       0      6
# 1201         Lvl    AllPub  ...    NaN    NaN         NaN       0      3
# 625          Lvl    AllPub  ...    NaN    NaN         NaN       0      2
# 898          Lvl    AllPub  ...    NaN    NaN         NaN       0      3
# 668          Bnk    AllPub  ...    NaN    NaN         NaN       0     11
#
#      YrSold SaleType  SaleCondition  SalePrice  prediction_label
# 594    2008       WD         Normal     110000     114933.333179
# 1294   2006       WD         Normal     115000     117130.255836
# 351    2006       WD        Abnorml     190000     207460.671948
# 603    2010       WD         Normal     151000     156394.652510
# 172    2006       WD         Normal     239000     188735.232389
# ...     ...      ...            ...        ...               ...
# 405    2009       WD         Normal     150000     154890.768216
# 1201   2009       WD         Normal     197900     196169.732578
# 625    2010       WD         Normal     160000     144321.878997
# 898    2010      New        Partial     611657     468482.046142
# 668    2006       WD         Normal     168000     173989.983465
#
# [439 rows x 82 columns]

# %%
final_model = finalize_model(best_model)
